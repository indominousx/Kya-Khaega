# %%
# %matplotlib inline
import ntlk
ntlk.donwload('stopwords')
ntlk.download('punkt')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[45], line 2
#       1 get_ipython().run_line_magic('matplotlib', 'inline')
# ----> 2 import ntlk
#       3 ntlk.donwload('stopwords')
#       4 ntlk.download('punkt')
#
# ModuleNotFoundError: No module named 'ntlk'

# %%
import pandas as pd
import math
df1=pd.read_csv(r'D:\Kya-Khaega\backend\NewZomatoDataset.csv')
df2=pd.read_csv('The_file.csv')
df1.info()
df1['Dining_Rating']=pd.to_numeric(df['Dining_Rating'],errors='coerce')
df1['Votes']=pd.to_numeric(df1['Votes'],errors='coerce')
df1.info()
print(df1['Dining_Rating'].isna().sum())
mean=df2['Dining_Rating'].mean()
mean2=df2['Votes'].mean()
print(mean)
print(mean2)
df1['Dining_Rating']=df1['Dining_Rating'].fillna(math.floor(mean))
df1['Votes']=df1['Votes'].fillna(math.floor(mean2))
df1.isna().sum()

df1.to_csv('The_file.csv',index=False)
df1
# Out:
# C:\Users\krish\AppData\Local\Temp\ipykernel_16824\2869950796.py:3: DtypeWarning: Columns (9) have mixed types. Specify dtype option on import or set low_memory=False.
#   df1=pd.read_csv(r'D:\Kya-Khaega\backend\NewZomatoDataset.csv')
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 88142 entries, 0 to 88141
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   URL              88142 non-null  object
#  1   Restaurant_Name  87727 non-null  object
#  2   Category         87727 non-null  object
#  3   Item_Name        88142 non-null  object
#  4   Price            87727 non-null  object
#  5   Food Type        88142 non-null  object
#  6   Cuisine          88142 non-null  object
#  7   Area             88142 non-null  object
#  8   Dining_Rating    87889 non-null  object
#  9   Votes            87889 non-null  object
# dtypes: object(10)
# memory usage: 6.7+ MB
# <class 'pandas.core.frame.DataFrame'>
# ...

# %%
dfnew=pd.read_csv('The_file.csv')
dfnew.sample(10)
# Out:
#                                              URL                                          \
# 43826              https://www.zomato.com/pune/bhairavee-pure-veg-restaurant-baner/order
# 67993                          https://www.zomato.com/pune/special-15-thalis-narhe/order
# 42579                  https://www.zomato.com/pune/trp-the-rooftop-project-mg-road/order
# 30605              https://www.zomato.com/pune/lotus-court-family-resto-bar-pimpri/order
# 28609                          https://www.zomato.com/pune/marrakesh-kalyani-nagar/order
# 87854                           https://www.zomato.com/pune/box8-desi-meals-katraj/order
# 53346           https://www.zomato.com/pune/poona-food-truck-1-senapati-bapat-road/order
# 52114                          https://www.zomato.com/pune/multi-spice-karve-nagar/order
# 41896                                   https://www.zomato.com/pune/kimchi-kharadi/order
# ...

# %%
from autoviz.AutoViz_Class import AutoViz_Class
AV=AutoViz_Class()
AV.AutoViz("",dfte=dfnew)
# Out:
# Shape of your Data Set loaded: (88142, 10)
# #######################################################################################
# ######################## C L A S S I F Y I N G  V A R I A B L E S  ####################
# #######################################################################################
# Classifying variables in data set...
#     Number of Numeric Columns =  2
#     Number of Integer-Categorical Columns =  0
#     Number of String-Categorical Columns =  2
#     Number of Factor-Categorical Columns =  0
#     Number of String-Boolean Columns =  1
#     Number of Numeric-Boolean Columns =  0
#     Number of Discrete String Columns =  2
#     Number of NLP String Columns =  3
#     Number of Date Time Columns =  0
#     Number of ID Columns =  0
#     Number of Columns to Delete =  0
#     10 Predictors classified...
#         No variables removed since no ID or low-information variables found in data set
# ...
